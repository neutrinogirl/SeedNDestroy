// %%
R__LOAD_LIBRARY(libRATEvent.so)

// %%
#include <Wrapper.hh>
#include <Hit.hh>

// %%
wRAT w("../inputs/theia_90pct_9000_35000_wbls_3pct/geoneutrino/theia_90pct_9000_35000_wbls_3pct_geoneutrino_1ZY7R3_0.root")
// Out:
// (wRAT &) @0x7f6e8fe46088

// %%
w.SetEvt(0);
w.GetPosTrue(0).Print();
// Out:
// TVector3 A 3D physics vector (x,y,z)=(-1804.390329,1886.149836,-112.568808) (rho,theta,phi)=(2612.672463,92.469393,133.730888)

// %%
const int nTrig = w.GetNTriggers()
// Out:
// (const int) 2

// %%
TCanvas *c = new TCanvas("c", "c", 800, 600);
c->Draw();
TH1D* hTRes = w.GetHTRes(0);
hTRes->Draw("HIST");
